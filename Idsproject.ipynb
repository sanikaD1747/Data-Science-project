# %% [markdown]
# #BOOK RECOMMENDATION SYSTEM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('bookRD/Books.csv')
# Out:
# C:\Users\sanika d\AppData\Local\Temp\ipykernel_9372\3467731138.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('bookRD/Books.csv')

# %%
books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
books.shape
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books =books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
       'Image-URL-S']]

# %%
books.rename(columns={
     
     'BooK-Title':'Title',
      'Book-Author': 'Author',

      'Year-Of-Publication': 'Year',

      'Publisher': 'Publisher'
    

}
             )
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       Author  Year  \
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# ...

# %%
users = pd.read_csv('bookRD/Users.csv')

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings = pd.read_csv('bookRD/ratings.csv', sep=";", encoding='latin1', on_bad_lines='skip')

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 6)
# (278858, 3)
# (1149780, 3)

# %%
x=ratings['User-ID'].value_counts() >200

# %%
y=x[x].index

# %%
ratings[ratings['User-ID'].isin(y)] #gives user who have rated more than 200 books
# Out:
#          User-ID        ISBN  Book-Rating
# 1456      277427  002542730X           10
# 1457      277427  0026217457            0
# 1458      277427  003008685X            8
# 1459      277427  0030615321            0
# 1460      277427  0060002050            0
# ...          ...         ...          ...
# 1147612   275970  3829021860            0
# 1147613   275970  4770019572            0
# 1147614   275970   896086097            0
# 1147615   275970  9626340762            8
# 1147616   275970  9626344990            0
#
# [526356 rows x 3 columns]

# %%
books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
ratings_with_books =ratings.merge(books, on="ISBN")

# %%
ratings_with_books.head()
#books who got ratings for more then 200 times
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                2002  Ballantine Books
# 3                2002  Ballantine Books
# 4                2002  Ballantine Books
#
#                                          Image-URL-S
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# ...

# %%
ratings_with_books.shape
# Out:
# (1031136, 8)

# %%
num_rating=ratings_with_books.groupby('Book-Title')['Book-Rating'].count().reset_index()

# %%
num_rating.head
# Out:
# <bound method NDFrame.head of                                                Book-Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]>

# %%
num_rating.rename(columns={'Book-Rating':'num_of_rating'

}

)
# Out:
#                                                Book-Title  num_of_rating
# 0        A Light in the Storm: The Civil War Diary of ...              4
# 1                                   Always Have Popsicles              1
# 2                    Apple Magic (The Collector's series)              1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...              1
# 4        Beyond IBM: Leadership Marketing and Finance ...              1
# ...                                                   ...            ...
# 241066                                      Ã?Â?lpiraten.              2
# 241067                     Ã?Â?rger mit Produkt X. Roman.              4
# 241068                                Ã?Â?sterlich leben.              1
# 241069                              Ã?Â?stlich der Berge.              3
# 241070                                  Ã?Â?thique en toc              2
#
# [241071 rows x 2 columns]

# %%
ratings_with_books.head
# Out:
# <bound method NDFrame.head of          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
final_ratings =ratings_with_books.merge(num_rating,on='Book-Title')

# %%
final_ratings.head(2)
# Out:
#    User-ID        ISBN  Book-Rating_x            Book-Title Book-Author  \
# 0   276725  034545104X              0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X              5  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
#
#                                          Image-URL-S  Book-Rating_y
# 0  http://images.amazon.com/images/P/034545104X.0...             60
# 1  http://images.amazon.com/images/P/034545104X.0...             60

# %%
#books who  got more then 50 rating
# Assuming 'final_ratings' is your DataFrame and 'num_rating' is the column name for the number of ratings
# Print the column names of your DataFrame
print(final_ratings.columns)
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating_x', 'Book-Title', 'Book-Author',
#        'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Book-Rating_y'],
#       dtype='object')

# %%
#for the books who got more tah 50 ratings
final_ratings['total_rating'] = final_ratings['Book-Rating_x'] + final_ratings['Book-Rating_y']
filtered_ratings = final_ratings[final_ratings['total_rating'] >= 50]
print(filtered_ratings)
# Out:
#         User-ID        ISBN  Book-Rating_x               Book-Title  \
# 0        276725  034545104X              0     Flesh Tones: A Novel
# 1          2313  034545104X              5     Flesh Tones: A Novel
# 2          6543  034545104X              0     Flesh Tones: A Novel
# 3          8680  034545104X              5     Flesh Tones: A Novel
# 4         10314  034545104X              9     Flesh Tones: A Novel
# ...         ...         ...            ...                      ...
# 788804   164728  0140430105              9  Emma (Penguin Classics)
# 788806   194646  0140430105             10  Emma (Penguin Classics)
# 788810   247429  0140430105             10  Emma (Penguin Classics)
# 788823   150762  0140434151              9  Emma (Penguin Classics)
# 788824   184632  0140434151              9  Emma (Penguin Classics)
#
#         Book-Author Year-Of-Publication         Publisher  \
# 0        M. J. Rose                2002  Ballantine Books
# ...

# %%
filtered_ratings.shape
# Out:
# (298435, 10)

# %%
filtered_ratings.drop_duplicates()
# Out:
#         User-ID        ISBN  Book-Rating_x               Book-Title  \
# 0        276725  034545104X              0     Flesh Tones: A Novel
# 1          2313  034545104X              5     Flesh Tones: A Novel
# 2          6543  034545104X              0     Flesh Tones: A Novel
# 3          8680  034545104X              5     Flesh Tones: A Novel
# 4         10314  034545104X              9     Flesh Tones: A Novel
# ...         ...         ...            ...                      ...
# 788804   164728  0140430105              9  Emma (Penguin Classics)
# 788806   194646  0140430105             10  Emma (Penguin Classics)
# 788810   247429  0140430105             10  Emma (Penguin Classics)
# 788823   150762  0140434151              9  Emma (Penguin Classics)
# 788824   184632  0140434151              9  Emma (Penguin Classics)
#
#         Book-Author Year-Of-Publication         Publisher  \
# 0        M. J. Rose                2002  Ballantine Books
# ...

# %%
filtered_ratings.shape
# Out:
# (298435, 10)

# %%
print(filtered_ratings)
# Out:
#         User-ID        ISBN  Book-Rating_x               Book-Title  \
# 0        276725  034545104X              0     Flesh Tones: A Novel
# 1          2313  034545104X              5     Flesh Tones: A Novel
# 2          6543  034545104X              0     Flesh Tones: A Novel
# 3          8680  034545104X              5     Flesh Tones: A Novel
# 4         10314  034545104X              9     Flesh Tones: A Novel
# ...         ...         ...            ...                      ...
# 788804   164728  0140430105              9  Emma (Penguin Classics)
# 788806   194646  0140430105             10  Emma (Penguin Classics)
# 788810   247429  0140430105             10  Emma (Penguin Classics)
# 788823   150762  0140434151              9  Emma (Penguin Classics)
# 788824   184632  0140434151              9  Emma (Penguin Classics)
#
#         Book-Author Year-Of-Publication         Publisher  \
# 0        M. J. Rose                2002  Ballantine Books
# ...

# %%
book_pivot =filtered_ratings.pivot_table(columns='User-ID',index='Book-Title',values='total_rating' )

# %%
book_pivot
# Out:
# User-ID                                             8       9       14      \
# Book-Title
# 'Salem's Lot                                           NaN     NaN     NaN
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# e                                                      NaN     NaN     NaN
# stardust                                               NaN     NaN     NaN
#
# ...

# %%
book_pivot.shape
# Out:
# (3207, 49281)

# %%
book_pivot.fillna(0)
# Out:
# User-ID                                             8       9       14      \
# Book-Title
# 'Salem's Lot                                           0.0     0.0     0.0
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# ...

# %%
import scipy as scipy

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <3207x49281 sparse matrix of type '<class 'numpy.float64'>'
# 	with 158044167 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
from sklearn.impute import SimpleImputer
from sklearn.neighbors import NearestNeighbors

# Assuming book_sparse is your input data with NaN values
# Impute missing values
imputer = SimpleImputer(strategy='mean')
book_sparse_imputed = imputer.fit_transform(book_sparse)

# Fit the model
model = NearestNeighbors(algorithm='brute')
model.fit(book_sparse_imputed)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
from sklearn.impute import SimpleImputer
from sklearn.neighbors import NearestNeighbors


# Impute missing values
imputer = SimpleImputer(strategy='mean')
book_pivot_imputed = imputer.fit_transform(book_pivot)

# Fit the model
model = NearestNeighbors(algorithm='brute')
model.fit(book_pivot_imputed)

# Get recommendations
distance, suggestions = model.kneighbors(book_pivot_imputed[237, :].reshape(1, -1), n_neighbors=6)

# %% [markdown]
# distance

# %%
suggestions
# Out:
# array([[ 237,  415,  283, 3177,  946,  122]], dtype=int64)

# %%
for i in range( len(suggestions)):
     print(book_pivot.index[suggestions[i]])
# Out:
# Index(['Armageddon: The Cosmic Battle of the Ages (Left Behind #11)',
#        'By the Book (Harlequin Blaze, No 85)', 'Beast',
#        'Wonder Boys : A Novel (Bestselling Backlist)',
#        'Generation Golf. Eine Inspektion', 'ACCORDION CRIMES'],
#       dtype='object', name='Book-Title')

# %%
book_pivot.index[3]
# Out:
# '1984'

# %%
books_name =book_pivot.index

# %%
import pickle
pickle.dump(model, open('artifacts/model.pkl', 'wb'))
pickle.dump(books_name, open('artifacts/book_name.pkl', 'wb'))
pickle.dump(filtered_ratings, open('artifacts/filtered_ratings.pkl', 'wb'))
pickle.dump(book_pivot, open('artifacts/book_pivoit.pkl', 'wb'))

# %%
np.where(book_pivot.index == "Zoya")
# Out:
# (array([3202], dtype=int64),)

# %%
#teating the recommender process
def recommend_book(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestions = model.kneighbors(book_pivot_imputed[book_id, :].reshape(1, -1), n_neighbors=6)

    for i in range( len(suggestions)):
        books = book_pivot.index[suggestions[i]]
        for j in books:
            print(j)

# %%
book_name = 'stardust'
recommend_book(book_name)
# Out:
# stardust
# Murder in Foggy Bottom (Truman, Margaret, Capital Crimes Series.)
# Beast
# Wonder Boys : A Novel (Bestselling Backlist)
# By the Book (Harlequin Blaze, No 85)
# ACCORDION CRIMES
